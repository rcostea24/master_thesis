# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
csv_data = pd.read_csv("fmri_full_data_11_23_2024.csv")

# %%
csv_data
# Out:
#      Image Data ID     Subject Group Sex  Age Visit Modality  \
# 0          I763762  036_S_5271   SMC   M   84   v31     fMRI
# 1         I1499309  082_S_5282   SMC   M   74    y2     fMRI
# 2          I673835  941_S_5124   SMC   F   79   v21     fMRI
# 3          I419124  009_S_5125   SMC   F   66   v11     fMRI
# 4          I561332  082_S_5282   SMC   M   69   v21     fMRI
# ...            ...         ...   ...  ..  ...   ...      ...
# 8886       I313392  014_S_4615    AD   M   87   v04     fMRI
# 8887       I341094  037_S_4770    AD   M   76   v04     fMRI
# 8888      I1162181  082_S_6690    AD   F   68    sc     fMRI
# 8889       I258955  019_S_4252    AD   F   87   v02     fMRI
# 8890       I350263  137_S_4756    AD   M   85   v05     fMRI
#
#              Description      Type    Acq Date Format  Downloaded
# 0             MoCoSeries  Original   8/03/2016    DCM  10/08/2024
# 1                 relCBF  Original  10/20/2020    DCM  10/09/2024
# ...

# %%
csv_data["Group"].unique()
# Out:
# array(['SMC', 'Patient', 'MCI', 'LMCI', 'EMCI', 'CN', 'AD'], dtype=object)

# %%
group_counts = csv_data["Group"].value_counts()

plt.figure(figsize=(10, 6))
plt.bar(group_counts.index, group_counts.values, color='skyblue', edgecolor='black')
plt.xlabel('Group Categories')
plt.ylabel('Frequency')
plt.title('Histogram of Group Categories')
plt.xticks(rotation=45)
plt.tight_layout()

# %%
print(len(csv_data[csv_data["Group"] == "Patient"]))
csv_data = csv_data[csv_data["Group"] != "Patient"]
# Out:
# 9

# %%
group_counts = csv_data["Group"].value_counts()

plt.figure(figsize=(10, 6))
plt.bar(group_counts.index, group_counts.values, color='skyblue', edgecolor='black')
plt.xlabel('Group Categories')
plt.ylabel('Frequency')
plt.title('Histogram of Group Categories')
plt.xticks(rotation=45)
plt.tight_layout()
